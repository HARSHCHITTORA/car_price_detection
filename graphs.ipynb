# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:\\Users\\nikku\\Desktop\\CU downloads\\SEMESTER 5\\Project\\Beta project\\Cleaned_Car_data.csv")

# %%
x=df['Price']
plt.boxplot(x)
plt.show()

# %%
df2=pd.read_csv("C:\\Users\\nikku\\Desktop\\CU downloads\\SEMESTER 5\\Project\\Project\\Car_data.csv")

# %%
import seaborn as sn
x=df['Price']
center=0
hm = sn.heatmap(df.corr(),annot=True)
plt.show()
